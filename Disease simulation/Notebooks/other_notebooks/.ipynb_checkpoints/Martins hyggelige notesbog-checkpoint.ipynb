# %%
import pandas  as pd
import networkx as nx
import re
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATA THINGY

# %%
#Our flitered dataset

# %%
data = pd.read_csv("../../Data/final_cool_dataset.csv")

# %%
#Coordinates from 1st dataset

# %%
coordinates_df = pd.read_csv("../../Data/Airports.csv")
# Out:
# /home/markus/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (51,52,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
coordinates_df = coordinates_df.rename(columns={'Y': 'LAT', 'X': 'LONG'})
coordinates_df = coordinates_df[["LONG","LAT","Loc_Id"]]

# %%
s_1 = set(coordinates_df["Loc_Id"])

# %%
#2nd dataset

# %%
new_names = pd.read_csv("../../Data/us-airports.csv")
new_names = new_names[["latitude_deg","longitude_deg","local_code"]]
new_names = new_names.iloc[1: , :]
new_names = new_names[new_names['local_code'].notna()]
new_names = new_names.rename(columns = {"local_code" :"ORIGIN"})

# %%
s_2 = set(new_names["ORIGIN"])

# %% [markdown]
# ## Airports which we do not have coordinates for

# %%
all_airpor_keys = s_1.union(s_2)
set(data["ORIGIN"]) - all_airpor_keys
# Out:
# {'ABL',
#  'AET',
#  'AIN',
#  'AKB',
#  'AOS',
#  'ATT',
#  'BFB',
#  'BFT',
#  'BKC',
#  'BKG',
#  'BLD',
#  'CDL',
#  'CIL',
#  'CKD',
#  'CLD',
#  'CLU',
#  'CYF',
#  'CYM',
#  'DGB',
#  'DIO',
#  'DJN',
#  'DOF',
#  'DRF',
#  'DRG',
#  'EDA',
#  'EGX',
#  'EMK',
#  'ESD',
#  'FCA',
#  'FID',
#  'FRD',
#  'FRY',
#  'FWL',
#  'GEK',
#  'GMT',
#  'HAR',
#  'HBH',
#  'HGZ',
#  'HHH',
#  'HKB',
#  'HLI',
#  'HSH',
#  'HSL',
#  'IRC',
#  'ISS',
#  'KBC',
#  'KCG',
#  'KCQ',
#  'KEH',
#  'KGK',
#  'KKH',
#  'KLL',
#  'KLN',
#  'KLW',
#  'KMO',
#  'KNK',
#  'KOT',
#  'KOZ',
#  'KPM',
#  'KPN',
#  'KPV',
#  'KUK',
#  'KWN',
#  'LIJ',
#  'LIV',
#  'LKE',
#  'LMA',
#  'LNI',
#  'LPS',
#  'LVD',
#  'MDR',
#  'MEO',
#  'MLL',
#  'MNT',
#  'MQT',
#  'MVW',
#  'MXY',
#  'NAD',
#  'NCN',
#  'NHZ',
#  'NIB',
#  'NKI',
#  'NLG',
#  'NME',
#  'NNK',
#  'NNL',
#  'NPT',
#  'NUP',
#  'ODW',
#  'OHC',
#  'OLH',
#  'ORV',
#  'OTS',
#  'PBK',
#  'PCT',
#  'PDB',
#  'PGC',
#  'PIP',
#  'PML',
#  'PPV',
#  'PQS',
#  'PTA',
#  'PUO',
#  'RBH',
#  'RBN',
#  'RDB',
#  'RLU',
#  'RSJ',
#  'SCE',
#  'SCF',
#  'SKK',
#  'STG',
#  'SYB',
#  'TEH',
#  'TEK',
#  'TLA',
#  'TNK',
#  'TWA',
#  'TWD',
#  'UGI',
#  'UST',
#  'UTM',
#  'UUK',
#  'VIK',
#  'WAA',
#  'WFB',
#  'WHD',
#  'WKK',
#  'WMK',
#  'WOW',
#  'WSX',
#  'WTL',
#  'WWA',
#  'WWP',
#  'WYB',
#  'XXU',
#  'YUM'}

# %%
#Merge coordinates to dataset

# %%
data = data.merge(new_names, on = "ORIGIN")
data = data.rename(columns = {"latitude_deg": "ORIGIN_LAT", "longitude_deg": "ORIGIN_LONG"})
new_names = new_names.rename(columns = {"ORIGIN" :"DEST"})
data = data.merge(new_names, on = "DEST")
data = data.rename(columns = {"latitude_deg": "DEST_LAT", "longitude_deg": "DEST_LONG"})

# %%
data
# Out:
#       ORIGIN DEST     PAYLOAD  DISTANCE    SEATS  PASSENGERS  \
# 0        ANC  OME  33729908.0     539.0  31762.0     20623.0
# 1        ATK  OME      4500.0     463.0     19.0         0.0
# 2        AUK  OME     39300.0     129.0     26.0         7.0
# 3        BET  OME     84200.0     283.0    346.0       260.0
# 4        BRW  OME     59180.0     520.0    253.0       132.0
# ...      ...  ...         ...       ...      ...         ...
# 19004    MTM  KPB      1850.0     116.0      6.0         0.0
# 19005    LGD  HES      6900.0      71.0      0.0         0.0
# 19006    OXR  CCR      2000.0     306.0      8.0         3.0
# 19007    HAO  UOX      2000.0     442.0      8.0         2.0
# 19008    IJX  MFI      2000.0     336.0      8.0         2.0
#
#        DEPARTURES_PERFORMED  \
# 0                    1133.0
# 1                       1.0
# 2                       9.0
# 3                      18.0
# 4                      13.0
# ...                     ...
# 19004                   1.0
# 19005                   2.0
# 19006                   1.0
# 19007                   1.0
# 19008                   1.0
#
#                                             CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0      ['Era Aviation' 'Alaska Airlines Inc.'\n 'Tato...            10299.0
# 1                          ['Hageland Aviation Service']            10396.0
# 2      ['Arctic Transportation' 'Bering Air Inc.' 'Ha...            10416.0
# 3      ['Hageland Aviation Service' 'Bering Air Inc.'...            10551.0
# 4      ['Bering Air Inc.' 'Era Aviation' 'Hageland Av...            10754.0
# ...                                                  ...                ...
# 19004    ['Venture Travel LLC d/b/a Taquan Air Service']            13504.0
# 19005  ['Empire Airlines Inc.' 'Federal Express Corpo...            12956.0
# 19006                              ['Avjet Corporation']            13988.0
# 19007                              ['Avjet Corporation']            12068.0
# 19008                              ['Avjet Corporation']            12310.0
#
#        DEST_AIRPORT_ID                                        ORIGIN_NAME  \
# 0              13873.0  Anchorage, AK: Ted Stevens Anchorage Internati...
# 1              13873.0   Atqasuk, AK: Atqasuk Edward Burnell Sr. Memorial
# 2              13873.0                     Alakanuk, AK: Alakanuk Airport
# 3              13873.0                         Bethel, AK: Bethel Airport
# 4              13873.0        Barrow, AK: Wiley Post/Will Rogers Memorial
# ...                ...                                                ...
# 19004          12773.0                        Metlakatla, AK: Metlakatala
# 19005          12103.0              La Grande, OR: La Grande/Union County
# 19006          10910.0                         Oxnard/Ventura, CA: Oxnard
# 19007          15481.0   Hamilton, OH: Butler County Regional Hogan Field
# 19008          13260.0           Jacksonville, IL: Jacksonville Municipal
#
#                                   DEST_NAME          ORIGIN_LAT  \
# 0                    Nome, AK: Nome Airport             61.1744
# 1                    Nome, AK: Nome Airport            70.46704
# 2                    Nome, AK: Nome Airport  62.680042266799994
# 3                    Nome, AK: Nome Airport         60.77980042
# 4                    Nome, AK: Nome Airport           71.285402
# ...                                     ...                 ...
# 19004  Point Baker, AK: Point Baker Airport           55.131001
# 19005    Hermiston, OR: Hermiston Municipal       45.2901992798
# 19006           Concord, CA: Buchanan Field     34.200801849365
# 19007         Oxford, MS: University-Oxford  39.363800048799995
# 19008  Marshfield, WI: Marshfield Municipal  39.774600982666016
#
#               ORIGIN_LONG           DEST_LAT            DEST_LONG
# 0             -149.996002  64.51219940185547  -165.44500732421875
# 1             -157.436013  64.51219940185547  -165.44500732421875
# 2          -164.659927368  64.51219940185547  -165.44500732421875
# 3            -161.8379974  64.51219940185547  -165.44500732421875
# 4             -156.766008  64.51219940185547  -165.44500732421875
# ...                   ...                ...                  ...
# 19004         -131.578003      56.3518981934       -133.623001099
# 19005      -118.007003784      38.6534996033       -122.899002075
# 19006    -119.20700073242      37.9897003174       -122.056999207
# 19007      -84.5220031738    34.384300231934     -89.536796569824
# 19008  -90.23829650878906      44.6369018555   -90.18930053710001
#
# [19009 rows x 16 columns]

# %% [markdown]
# ## Create json lookup tables

# %%
#Abbreviation (Local code)

# %%
abv_list = list(zip(data["ORIGIN"],data["ORIGIN_LAT"], data["ORIGIN_LONG"]))

# %%
abv_lookup_table = dict()
for elm in abv_list:
    abv_lookup_table[elm[0]] = (elm[1], elm[2])

# %%
with open("../../Data/abv_lookup_table.json", "w") as outfile:
    json.dump(abv_lookup_table, outfile)

# %%
#Names (Full airport name incl state)

# %%
name_list = list(zip(data["ORIGIN_NAME"],data["ORIGIN_LAT"], data["ORIGIN_LONG"]))

# %%
airport_lookup_table = dict()
for elm in name_list:
    airport_lookup_table[elm[0]] = (elm[1], elm[2])

# %%
with open("../../Data/airport_names_lookup_table.json", "w") as outfile:
    json.dump(airport_lookup_table, outfile)

# %% [markdown]
# ## Graph

# %%
edges = [(row['ORIGIN_NAME'], row['DEST_NAME'], {'weight': row['PASSENGERS']}) for _, row in data.iterrows()]

# %%
G = nx.DiGraph()
G.add_edges_from(edges)

# %%
nx.is_strongly_connected(G)
# Out:
# False

# %%
#Isolated nodes

# %%
components = sorted(nx.strongly_connected_components(G), key=len, reverse=True)
components[1:]
# Out:
# [{'Circle Hot Springs, AK: Circle Hot Springs Airport'}]

# %%
to_removed = [list(x) for x in components  if x != max(components)]
flat_list = [item for sublist in to_removed for item in sublist]
G.remove_nodes_from(flat_list)
nx.is_strongly_connected(G)
# Out:
# True

# %% [markdown]
# Here we find that the diameter of the graph is 7
# This means that you can get from any airport to any airport in at most 7 steps.
# The longest shortest path is 7

# %%
nx.diameter(G)
# Out:
# 7

# %% [markdown]
# This is the average shortest path of the network. Meaning on average if you pick two nodes at random the distance is a path with the length of 3

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.975030774994648

# %% [markdown]
# Finding the longest shortest paths

# %%
li = []
for node in G.nodes():
    start_end_nodes = [(node, k) for k,v in nx.shortest_path_length(G, node).items() if v == 7]
    if start_end_nodes != []:
        li.append(start_end_nodes)

# %%
routes = dict()
coord = dict()
for elm in li:
    from_ = elm[0][0]
    #routes[from_] = []
    routes_dict = dict()
    coord_dict = dict()
    for i in elm:
        to_ = i[1]
        shortest_path = nx.shortest_path(G, from_, to_)
        
        routes_dict[to_] = shortest_path
        coord_dict[to_] = [airport_lookup_table[x] for x in shortest_path]
        #airport_name_coordinates
        #coord_dict[to_] = [airport_name_coordinates(x) for x in shortest_path]
    coord[from_] = coord_dict
    routes[from_] = routes_dict

# %%
from_ = []
dest_ = []
coordinates = []
path = []
for elm in coord.items():
    fr = elm[0]
    
    for i in elm[1].keys():
        dest_.append(i)
        path.append(routes[fr][i])
        from_.append(fr)
    for i in elm[1].values():
        coordinates.append(i)

# %%
d = {"from": from_, "dest": dest_, "path": path, "coordinates": coordinates}
df_paths = pd.DataFrame(data=d)
df_paths.to_csv('../../Data/to_florian_dataframe_longest_paths.csv', index=False)

# %% [markdown]
# Centrality
#
# In graph theory and network analysis, indicators of centrality assign numbers or rankings to nodes within a graph corresponding to their network position. Applications include identifying the most influential person(s) in a social network,

# %%
sorted_degree_centrality = sorted(nx.degree_centrality(G).items(), key=lambda x: x[1], reverse=True)
sorted_degree_centrality = [x[0] for x in sorted_degree_centrality[0:20]]
#These are the most "central" nodes in the graph
sorted_degree_centrality
# Out:
# ['Atlanta, GA: Hartsfield-Jackson Atlanta International',
#  'Minneapolis, MN: Minneapolis-St Paul International',
#  'Denver, CO: Denver International',
#  "Chicago, IL: Chicago O'Hare International",
#  'Dallas/Fort Worth, TX: Dallas/Fort Worth International',
#  'Memphis, TN: Memphis International',
#  'Detroit, MI: Detroit Metro Wayne County',
#  'Houston, TX: George Bush Intercontinental/Houston',
#  'Los Angeles, CA: Los Angeles International',
#  'Las Vegas, NV: McCarran International',
#  'Louisville, KY: Louisville International-Standiford Field',
#  'Newark, NJ: Newark Liberty International',
#  'Washington, DC: Washington Dulles International',
#  'Detroit, MI: Willow Run',
#  'Charlotte, NC: Charlotte Douglas International',
#  'Anchorage, AK: Ted Stevens Anchorage International',
#  'Indianapolis, IN: Indianapolis International',
#  'Baltimore, MD: Baltimore/Washington International Thurgood Marshall',
#  'Miami, FL: Miami International',
#  'Burbank, CA: Bob Hope']

# %%
mask = data["ORIGIN_NAME"].isin(sorted_degree_centrality)
to_florian_dataframe_degree_centrality = data[mask][["ORIGIN_NAME","ORIGIN_LAT", "ORIGIN_LONG"]].drop_duplicates('ORIGIN_NAME', keep='last')
to_florian_dataframe_degree_centrality.to_csv('../../Data/to_florian_dataframe_degree_centrality.csv', index=False)

# %% [markdown]
# Clustering coefficient

# %%
#The average clustering coefficient of the network is 0.56
nx.average_clustering(G)
# Out:
# 0.5606808129882183

# %%
#Clustering for nodes
clustering = nx.clustering(G)
clustering_sorted = sorted(clustering.items(), key=lambda x: x[1], reverse=True)
clustering_sorted
# Out:
# [('Port Clarence, AK: Port Clarence CGS', 1.0),
#  ('Moses Point, AK: Moses Point Airport', 1.0),
#  ('Lik, AK: Lik Mining Camp', 1.0),
#  ('Ivotuk, AK: Ivotuk Airstrip', 1.0),
#  ('Yukon Charley Rivvers, AK: Coal Creek', 1.0),
#  ('Qugruc, AK: Qugruc Airport', 1.0),
#  ('Chicken, AK: Chicken Airport', 1.0),
#  ('Chisana, AK: Chisana Airport', 1.0),
#  ('Northway, AK: Northway Airport', 1.0),
#  ('Kiluda Bay, AK: Kiluda Bay Airport', 1.0),
#  ('Olga Bay, AK: Olga Bay Seaplane Base', 1.0),
#  ('Port Williams, AK: Port Williams Airport', 1.0),
#  ('Sitkinak, AK: Sitkinak CGS', 1.0),
#  ('Elizabeth Island, AK: Elizabeth Island Airport', 1.0),
#  ('Seldovia, AK: Seldovia Airport', 1.0),
#  ('Akun, AK: Akun Airport', 1.0),
#  ('Nikolski, AK: Nikolski AS', 1.0),
#  ('Adak Island, AK: Adak', 1.0),
#  ('Peru, IN: Grissom ARB', 1.0),
#  ('Montauk Point, NY: Sky Portal', 1.0),
#  ('El Dorado, AR: South Arkansas Regional at Goodwin Field', 1.0),
#  ('Burlington, IA: Southeast Iowa Regional', 1.0),
#  ('Decatur, IL: Decatur Airport', 1.0),
#  ('Valdosta, GA: Moody AFB', 1.0),
#  ('Lake Charles, LA: Chennault International', 1.0),
#  ('Brownwood, TX: Brownwood Regional', 1.0),
#  ('Schenectady, NY: Schenectady County', 1.0),
#  ('Hillsboro, OR: Portland Hillsboro', 1.0),
#  ('Livermore, CA: Livermore Municipal', 1.0),
#  ('Lawrence, KS: Lawrence Municipal', 1.0),
#  ('New Orleans, LA: Lakefront', 1.0),
#  ('Racine, WI: John H. Batten', 1.0),
#  ('San Bernardino, CA: San Bernardino International', 1.0),
#  ('Marana, AZ: Pinal Airpark', 1.0),
#  ('Victoria, TX: Victoria Regional', 1.0),
#  ('Great Bend, KS: Great Bend Municipal', 1.0),
#  ('McCook, NE: McCook Ben Nelson Regional', 1.0),
#  ('Silver City/Hurley, NM: Grant County', 1.0),
#  ('Walla Walla, WA: Walla Walla Regional', 1.0),
#  ('Port Angeles, WA: William R. Fairchild International', 1.0),
#  ('West Yellowstone, MT: Yellowstone', 1.0),
#  ('Davenport, IA: Davenport Municipal', 1.0),
#  ('Goshen, IN: Goshen Municipal', 1.0),
#  ('Ankeny, IA: Ankeny Regional', 1.0),
#  ('Mount Vernon, IL: Mount Vernon Airport', 1.0),
#  ('Ottumwa, IA: Ottumwa Regional', 1.0),
#  ('Springfield, OH: Springfield-Beckley Municipal', 1.0),
#  ('Wapakoneta, OH: Neil Armstrong', 1.0),
#  ('Clarks Point, AK: Clarks Point Airport', 1.0),
#  ('Portage Creek, AK: Portage Creek Airport', 1.0),
#  ('Middleton Island, AK: Middleton Island Airport', 1.0),
#  ('Colorado Creek, AK: Colorado Creek Airport', 1.0),
#  ('Waterfall, AK: Waterfall Seaplane Base', 1.0),
#  ('Kasaan, AK: Kasaan Seaplane Base', 1.0),
#  ('Steamboat Bay, AK: Steamboat Bay Airport', 1.0),
#  ('Granite Point, AK: Granite Point Ndb', 1.0),
#  ('Ephrata/Moses Lake, WA: Ephrata Municipal', 1.0),
#  ('Hermiston, OR: Hermiston Municipal', 1.0),
#  ('Kalaupapa, HI: Kalaupapa Airport', 1.0),
#  ('Fairbanks, AK: Eielson AFB', 1.0),
#  ('Augusta/Waterville, ME: Augusta State', 1.0),
#  ('Laconia, NH: Laconia Municipal', 1.0),
#  ('Provincetown, MA: Provincetown Municipal', 1.0),
#  ('Nebraska, NE: Nebraska City Municipal', 1.0),
#  ('Pittsburgh, PA: Allegheny County', 1.0),
#  ('Benton Harbor/St. Joseph, MI: Southwest Michigan Regional', 1.0),
#  ('Manassas, VA: Manassas Regional/Harry P. Davis Field', 1.0),
#  ('Morrisville, VT: Morrisville Stowe State', 1.0),
#  ('Sanford, ME: Sanford Seacoast Regional', 1.0),
#  ('Vero Beach, FL: Vero Beach Municipal', 1.0),
#  ('Beloit/Janesville, WI: Southern Wisconsin Regional', 1.0),
#  ('Chicago, IL: Chicago Executive', 1.0),
#  ('Beckley, WV: Raleigh County Memorial', 1.0),
#  ('Orlando, FL: Executive', 1.0),
#  ('Reading, PA: Reading Regional/Carl A Spaatz Field', 1.0),
#  ('Houma, LA: Houma Terrebonne', 1.0),
#  ('San Diego, CA: Miramar MCAS', 1.0),
#  ('New Bedford/Fall River, MA: New Bedford Regional', 1.0),
#  ('Kingston, NY: Kingston Ulster', 1.0),
#  ('Dublin, VA: New River Valley', 1.0),
#  ('San Antonio, TX: Lackland AFB (Kelly Field Annex)', 1.0),
#  ('Fort Huachuca, AZ: Sierra Vista Municipal-Libby AAF', 1.0),
#  ('Rutland, VT: Rutland - Southern Vermont Regional', 1.0),
#  ('Lake Placid, NY: Lake Placid Airport', 1.0),
#  ('Marathon, FL: The Florida Keys Marathon', 1.0),
#  ('Torrington, WY: Torrington Municipal', 1.0),
#  ('Tehachapi, CA: Tehachapi Municipal', 1.0),
#  ('Glasgow, MT: Wokal Field/Glasgow International', 1.0),
#  ('Havre, MT: Havre City-County', 1.0),
#  ('Lewistown, MT: Lewistown Municipal', 1.0),
#  ('Miles City, MT: Frank Wiley Field', 1.0),
#  ('Battle Creek, MI: W K Kellogg', 1.0),
#  ('Mansfield, OH: Mansfield Lahm Regional', 1.0),
#  ('Greeneville, TN: Municipal', 1.0),
#  ('Goodland, KS: Renner Field', 1.0),
#  ('Artesia, NM: Artesia Municipal', 1.0),
#  ('The Dalles, OR: Columbia Gorge Regional/The Dalles Municipal', 1.0),
#  ('Lakeview, OR: Lake County', 1.0),
#  ('Hudson, NY: Columbia County', 1.0),
#  ('Middlebury, VT: Middlebury State', 1.0),
#  ('Georgetown, DE: Sussex County', 1.0),
#  ('Keokuk, IA: Keokuk Municipal', 1.0),
#  ('Broken Bow, NE: Broken Bow Municipal Kieth Glaze Field', 1.0),
#  ('Paso Robles, CA: Paso Robles Municipal', 1.0),
#  ('Uvalde, TX: Garner Field', 1.0),
#  ('Brookings, OR: Brookings Airport', 1.0),
#  ('Santa Rosa, CA: Charles M. Schulz - Sonoma County', 0.9897959183673469),
#  ('Hilo, HI: Hilo International', 0.9666666666666667),
#  ('Tatalina, AK: Tatalina LRRS', 0.9607843137254902),
#  ('Chandalar, AK: Chandalar Lake', 0.96),
#  ('Gunnison, CO: Gunnison-Crested Butte Regional', 0.9545454545454546),
#  ('Altoona, PA: Altoona-Blair County', 0.9444444444444444),
#  ('Lancaster, PA: Lancaster Airport', 0.9444444444444444),
#  ('Skagway, AK: Skagway Airport', 0.9375),
#  ('Hobbs, NM: Lea County Regional', 0.9230769230769231),
#  ('Butte, MT: Bert Mooney', 0.9230769230769231),
#  ('Martinsburg, WV: Eastern WV Regional/Shepherd Field', 0.9230769230769231),
#  ('Hydaburg, AK: Hydaburg Seaplane Base', 0.92),
#  ('Stony River, AK: Stony River Airport', 0.9166666666666666),
#  ('Chignik Lagoon, AK: Chignik Lagoon Airport', 0.9024390243902439),
#  ('Rifle, CO: Garfield County Regional', 0.9),
#  ('Columbia, TN: Maury County', 0.9),
#  ('Hibbing, MN: Range Regional', 0.8947368421052632),
#  ('Central, AK: Central Airport', 0.8888888888888888),
#  ('Port Graham, AK: Port Graham Airport', 0.8888888888888888),
#  ('San Juan, AK: San Juan Airport', 0.875),
#  ('Vernal, UT: Vernal Regional', 0.875),
#  ('Franklin/Oil City, PA: Venango Regional', 0.875),
#  ('Gallup, NM: Gallup Municipal', 0.875),
#  ('Ekwok, AK: Ekwok Airport', 0.8688524590163934),
#  ('Kivalina, AK: Kivalina Airport', 0.8588235294117647),
#  ('Savoonga, AK: Savoonga Airport', 0.8529411764705882),
#  ('Alpine, AK: Alpine Airstrip', 0.8529411764705882),
#  ('Erie, PA: Erie International/Tom Ridge Field', 0.8502994011976048),
#  ('Akutan, AK: Akutan Airport', 0.8461538461538461),
#  ('Hana, HI: Hana Airport', 0.8461538461538461),
#  ('Peach Springs, AZ: Grand Canyon West', 0.8461538461538461),
#  ('Point Baker, AK: Point Baker Airport', 0.8461538461538461),
#  ('Key West, FL: Key West International', 0.8439086294416244),
#  ('Lihue, HI: Lihue Airport', 0.8436578171091446),
#  ('Tenakee, AK: Tenakee Airport', 0.84),
#  ('Hopkinsville, KY: Hopkinsville-Christian County', 0.8360655737704918),
#  ('Port Bailey, AK: Port Bailey Airport', 0.8333333333333334),
#  ('Zachar Bay, AK: Zachar Bay Airport', 0.8333333333333334),
#  ('Alliance, NE: Alliance Municipal', 0.8333333333333334),
#  ('Lancaster, CA: General William J. Fox Airfield', 0.8333333333333334),
#  ('Koyukuk, AK: Koyukuk Airport', 0.8320610687022901),
#  ('St. Paul, AK: St. Paul Island', 0.831858407079646),
#  ('Yakutat, AK: Yakutat Airport', 0.8163265306122449),
#  ('Walterboro, SC: Lowcountry Regional', 0.8157894736842105),
#  ('Haines, AK: Haines Airport', 0.8125),
#  ('Salisbury, MD: Salisbury-Ocean City/Wicomico Regional', 0.8115384615384615),
#  ('Nenana, AK: Nenana Municipal', 0.8095238095238095),
#  ('Dubuque, IA: Dubuque Regional', 0.8095238095238095),
#  ('St. Louis, MO: Spirit of St. Louis', 0.8091482649842271),
#  ('Minchumina, AK: Minchumina Airport', 0.8076923076923077),
#  ('Kinston, NC: Kinston Regional Jetport at Stallings Field',
#   0.8064516129032258),
#  ('Logan, UT: Logan Cache', 0.8055555555555556),
#  ('Metlakatla, AK: Metlakatala', 0.803921568627451),
#  ('Decatur, AL: Pryor Field Regional', 0.8018867924528302),
#  ('Eagle, CO: Eagle County Regional', 0.8013565891472868),
#  ('False Pass, AK: False Pass Airport', 0.8),
#  ('Nyac, AK: Nyac Airport', 0.8),
#  ('Flat, AK: Flat Airport', 0.8),
#  ('El Centro, CA: Imperial County', 0.8),
#  ('Mammoth Lakes, CA: Mammoth Lakes Airport', 0.8),
#  ('Wenatchee, WA: Pangborn Memorial', 0.8),
#  ('Cape Girardeau, MO: Cape Girardeau Regional', 0.8),
#  ('Muskegon, MI: Muskegon County', 0.7941176470588235),
#  ('Soldotna, AK: Soldotna Airport', 0.7894736842105263),
#  ('Saranac Lake/Lake Placid, NY: Adirondack Regional', 0.7894736842105263),
#  ('Ocala, FL: Ocala International-Jim Taylor Field', 0.7887931034482759),
#  ('Cleveland, OH: Burke Lakefront', 0.7861842105263158),
#  ('Sarasota/Bradenton, FL: Sarasota/Bradenton International',
#   0.7854460093896714),
#  ('Rome, NY: Griffiss International', 0.782608695652174),
#  ('Cortez, CO: Cortez Municipal', 0.7777777777777778),
#  ('Elfin Cove, AK: Elfin Cove Seaplane Base', 0.7777777777777778),
#  ('Valdez, AK: Valdez Pioneer Field', 0.7692307692307693),
#  ('Eau Claire, WI: Chippewa Valley Regional', 0.7673267326732673),
#  ('Point Lay, AK: Point Lay LRRS', 0.7660377358490567),
#  ('Nuiqsut, AK: Nuiqsut Airport', 0.7657657657657657),
#  ('Macon, GA: Middle Georgia Regional', 0.7651515151515151),
#  ('Sacramento, CA: Sacramento Mather', 0.7650602409638554),
#  ('Laramie, WY: Laramie Regional', 0.7623318385650224),
#  ('Karluk, AK: Karluk Airport', 0.76),
#  ('Roseburg, OR: Roseburg Regional', 0.7575757575757576),
#  ('White Mountain, AK: White Mountain Airport', 0.7562189054726368),
#  ('Umiat, AK: Umiat Airport', 0.7543859649122807),
#  ('Dahl Creek, AK: Dahl Creek Airport', 0.75),
#  ('Nanwalek, AK: Nanwalek Airport', 0.75),
#  ('International Falls, MN: Falls International', 0.75),
#  ('Lorain/Elyria, OH: Lorain County Regional', 0.75),
#  ('Lebanon-Hanover, NH: Lebanon Municipal', 0.75),
#  ('Norwood, MA: Norwood Memorial', 0.75),
#  ('Ukiah, CA: Ukiah Municipal', 0.75),
#  ('St. Louis, MO: Bi-State Parks', 0.7484848484848485),
#  ('South Naknek, AK: South Naknek 2', 0.7450980392156863),
#  ('Kona, HI: Kona International Airport at Keahole', 0.7441634241245136),
#  ('Koyuk, AK: Koyuk Alfred Adams', 0.7438524590163934),
#  ('Montrose/Delta, CO: Montrose Regional', 0.7433920704845814),
#  ('Houston, TX: Ellington', 0.7405405405405405),
#  ('Atqasuk, AK: Atqasuk Edward Burnell Sr. Memorial', 0.740484429065744),
#  ('Takotna, AK: Takotna Airport', 0.736318407960199),
#  ('Barter Island, AK: Barter Island LRRS', 0.7348066298342542),
#  ('Fort Dix, NJ: McGuire Field', 0.7294685990338164),
#  ('Albany, GA: Southwest Georgia Regional', 0.7260869565217392),
#  ('Thermal, CA: Jacqueline Cochran Regional', 0.725),
#  ('Kansas City, MO: Charles B. Wheeler Downtown', 0.7245762711864406),
#  ('Jackson, WY: Jackson Hole', 0.7235401459854015),
#  ('Merced, CA: Merced Regional/Macready Field', 0.7222222222222222),
#  ('Igiugig, AK: Igiugig Airport', 0.7213114754098361),
#  ('Crescent City, CA: Jack McNamara Field', 0.7211538461538461),
#  ('Worland, WY: Worland Municipal', 0.72),
#  ('Devils Lake, ND: Devils Lake Regional', 0.72),
#  ('Gustavus, AK: Gustavus Airport', 0.72),
#  ('Gambell, AK: Gambell Airport', 0.7192982456140351),
#  ('Sheldon Point, AK: Sheldon Point Airport', 0.7172413793103448),
#  ('Paducah, KY: Barkley Regional', 0.7171052631578947),
#  ('Monterey, CA: Monterey Regional', 0.7154907975460123),
#  ('Galbraith Lake, AK: Galbraith Lake Airport', 0.7142857142857143),
#  ('Prospect Creek, AK: Prospect Creek Airport', 0.7142857142857143),
#  ('Belleville, IL: Scott AFB/MidAmerica', 0.7142857142857143),
#  ('St. George, UT: St George Municipal', 0.7103960396039604),
#  ('Beaver, AK: Beaver Airport', 0.7103448275862069),
#  ('Mekoryuk, AK: Mekoryuk Airport', 0.7096774193548387),
#  ('Iron Mountain/Kingsfd, MI: Ford', 0.7094594594594594),
#  ('Aspen, CO: Aspen Pitkin County Sardy Field', 0.7089552238805971),
#  ('Angoon, AK: Angoon Seaplane Base', 0.7073170731707317),
#  ('Oscoda, MI: Oscoda-Wurtsmith', 0.7058823529411765),
#  ('Sleetmute, AK: Sleetmute Airport', 0.7034482758620689),
#  ('Bemidji, MN: Bemidji Regional', 0.7027027027027027),
#  ('Selawik, AK: Selawik Airport', 0.702054794520548),
#  ('Gillette, WY: Gillette Campbell County', 0.7),
#  ('Chadron, NE: Chadron Municipal', 0.7),
#  ('Jacksonville/Camp Lejeune, NC: Albert J Ellis', 0.6986607142857143),
#  ('Winston-Salem, NC: Smith Reynolds', 0.6977739726027398),
#  ('Huron, SD: Huron Regional', 0.696969696969697),
#  ('Kingman, AZ: Kingman Airport', 0.6923076923076923),
#  ('Binghamton, NY: Greater Binghamton/Edwin A. Link Field', 0.69),
#  ('Manchester, NH: Manchester-Boston Regional', 0.6894589244473771),
#  ('Port Heiden, AK: Port Heiden Airport', 0.6891891891891891),
#  ('Red Devil, AK: Red Devil Airport', 0.6885245901639344),
#  ('Palm Springs, CA: Palm Springs International', 0.6878212732305259),
#  ('San Diego, CA: Brown Field Municipal', 0.6857142857142857),
#  ('Pelican, AK: Pelican Seaplane Base', 0.6829268292682927),
#  ('Port Lions, AK: Port Lions Airport', 0.68),
#  ('Jamestown, ND: Jamestown Regional', 0.68),
#  ('Golovin, AK: Golovin Airport', 0.6762295081967213),
#  ('Shageluk, AK: Shageluk Airport', 0.6734177215189874),
#  ('Grayling, AK: Grayling Airport', 0.6731517509727627),
#  ('Elmira/Corning, NY: Elmira/Corning Regional', 0.6702702702702703),
#  ('Bloomington, IN: Monroe County', 0.6696914700544465),
#  ('Anvik, AK: Anvik Airport', 0.669260700389105),
#  ('Panama City, FL: Northwest Florida Beaches International',
#   0.6674008810572687),
#  ('Brunswick, GA: Malcolm McKinnon', 0.6666666666666666),
#  ('Clovis, NM: Clovis Municipal', 0.6666666666666666),
#  ('Phoenix, AZ: Phoenix - Deer Valley', 0.6666666666666666),
#  ('Roxboro, NC: Person County', 0.6666666666666666),
#  ('Lanai, HI: Lanai Airport', 0.6666666666666666),
#  ('San Diego, CA: North Island NAS', 0.6666666666666666),
#  ('Bar Harbor, ME: Hancock County-Bar Harbor', 0.6666666666666666),
#  ('El Centro, CA: El Centro NAF', 0.6666666666666666),
#  ('Danbury, CT: Danbury Municipal', 0.6666666666666666),
#  ('Pittsfield, MA: Pittsfield Municipal', 0.6666666666666666),
#  ('Glendive, MT: Dawson Community', 0.6666666666666666),
#  ('Fayetteville, NC: Pope AAF', 0.6666666666666666),
#  ('Bend/Redmond, OR: Roberts Field', 0.6650943396226415),
#  ('Scranton/Wilkes-Barre, PA: Wilkes Barre Scranton International',
#   0.6632312822067293),
#  ('Stebbins, AK: Stebbins Airport', 0.6603260869565217),
#  ('Excursion Inlet, AK: Excursion Inlet Seaplane Base', 0.6585365853658537),
#  ('Telluride, CO: Telluride Regional', 0.6578947368421053),
#  ('Hoolehua, HI: Molokai', 0.65625),
#  ('Elim, AK: Elim Airport', 0.6557377049180327),
#  ('Dickinson, ND: Dickinson - Theodore Roosevelt Regional',
#   0.6550387596899225),
#  ('Newburgh/Poughkeepsie, NY: Stewart International', 0.6542768273716951),
#  ('Kitoi Bay, AK: Kitoi Bay Airport', 0.6538461538461539),
#  ('Garden City, KS: Garden City Regional', 0.6533333333333333),
#  ('Moser Bay, AK: Moser Bay Airport', 0.6515151515151515),
#  ('Rochester, NY: Greater Rochester International', 0.6506357103372029),
#  ('Bartlesville, OK: Bartlesville Municipal', 0.65),
#  ('Beluga, AK: Beluga Airport', 0.65),
#  ('Melbourne, FL: Melbourne International', 0.649890590809628),
#  ('Burlington, VT: Burlington International', 0.6490510471204188),
#  ('Napa, CA: Napa County', 0.6481481481481481),
#  ('LaGrange, GA: LaGrange-Callaway', 0.646551724137931),
#  ('Stockton, CA: Stockton Metropolitan', 0.6463414634146342),
#  ('Lynchburg, VA: Lynchburg Regional/Preston Glenn Field', 0.6460176991150443),
#  ('Norfolk, VA: Norfolk NS', 0.6449704142011834),
#  ('Portland, ME: Portland International Jetport', 0.6449065543564095),
#  ('Greenville, NC: Pitt Greenville', 0.6448275862068965),
#  ('Bellingham, WA: Bellingham International', 0.6446601941747573),
#  ('Alpena, MI: Alpena County Regional', 0.6438356164383562),
#  ('Rhinelander, WI: Rhinelander/Oneida County', 0.6438356164383562),
#  ('Chico, CA: Chico Municipal', 0.6428571428571429),
#  ('Stillwater, OK: Stillwater Regional', 0.6412556053811659),
#  ('Brevig Mission, AK: Brevig Mission Airport', 0.6403508771929824),
#  ('Evansville, IN: Evansville Regional', 0.6400778210116731),
#  ('Napaskiak, AK: Napaskiak Airport', 0.6396551724137931),
#  ('Rochester, MN: Rochester International', 0.63916015625),
#  ('Nulato, AK: Nulato Airport', 0.6389645776566758),
#  ('Champaign/Urbana, IL: University of Illinois/Willard', 0.6388561320754716),
#  ('Cody, WY: Yellowstone Regional', 0.6363636363636364),
#  ('Anderson, SC: Anderson Regional', 0.6363636363636364),
#  ('Hollis, AK: Hollis Seaplane Base', 0.6363636363636364),
#  ('Visalia, CA: Visalia Municipal', 0.6346153846153846),
#  ('Owensboro, KY: Owensboro Daviess County', 0.631578947368421),
#  ('Daytona Beach, FL: Daytona Beach International', 0.6315543071161048),
#  ('Sun Valley/Hailey/Ketchum, ID: Friedman Memorial', 0.6310975609756098),
#  ('Hartford, CT: Bradley International', 0.6301519468186135),
#  ('Hayden, CO: Yampa Valley', 0.6276595744680851),
#  ('Santa Monica, CA: Santa Monica Municipal', 0.6270270270270271),
#  ('Islip, NY: Long Island MacArthur', 0.62656048213517),
#  ('Muscle Shoals, AL: Northwest Alabama Regional', 0.625),
#  ('La Grande, OR: La Grande/Union County', 0.625),
#  ('Akiachak, AK: Akiachak Airport', 0.6239782016348774),
#  ('Missoula, MT: Missoula International', 0.6230769230769231),
#  ('Allentown/Bethlehem/Easton, PA: Lehigh Valley International',
#   0.6229815996995869),
#  ('Bakersfield, CA: Meadows Field', 0.6224385245901639),
#  ('Athens, GA: Athens/Ben Epps', 0.6212121212121212),
#  ('Dallas/Fort Worth, TX: Fort Worth Alliance', 0.6209906617945595),
#  ('Bishop, CA: Eastern Sierra Regional', 0.62),
#  ('Muncie/Anderson/Newcastle, IN: Delaware County Regional',
#   0.6190476190476191),
#  ('Sault Ste. Marie, MI: Chippewa County International', 0.6176470588235294),
#  ('Fort Myers, FL: Southwest Florida International', 0.617270684770929),
#  ('Traverse City, MI: Cherry Capital', 0.6171122994652406),
#  ('Columbia, MO: Columbia Regional', 0.6163079470198676),
#  ('Akiak, AK: Akiak Airport', 0.615916955017301),
#  ('Longview, TX: East Texas Regional', 0.6158940397350994),
#  ('Topeka, KS: Forbes Field', 0.6154639175257732),
#  ('Meridian, MS: Key Field', 0.6153846153846154),
#  ('San Luis Obispo, CA: San Luis County Regional', 0.6148648648648649),
#  ('Chuathbaluk, AK: Chuathbaluk Airport', 0.6134020618556701),
#  ('King Cove, AK: King Cove Airport', 0.6124031007751938),
#  ('Lafayette, IN: Purdue University', 0.6123595505617978),
#  ('Fayetteville, NC: Fayetteville Regional/Grannis Field', 0.6121399176954733),
#  ('Rampart, AK: Rampart Airport', 0.611764705882353),
#  ('Providence, RI: Theodore Francis Green State', 0.611268603827073),
#  ('Morristown, NJ: Morristown Municipal', 0.6111111111111112),
#  ('Sheridan, WY: Sheridan County', 0.6097560975609756),
#  ('Show Low, AZ: Show Low Regional', 0.6097560975609756),
#  ('Kapalua, HI: Kapalua Airport', 0.6097560975609756),
#  ('Charleston/Dunbar, WV: Yeager', 0.6080790717662226),
#  ('New Haven, CT: Tweed New Haven', 0.6078431372549019),
#  ('Pullman, WA: Pullman Moscow Regional', 0.6076233183856502),
#  ('Tuluksak, AK: Tuluksak Airport', 0.6073529411764705),
#  ('Inyokern, CA: Inyokern Airport', 0.6052631578947368),
#  ('Brunswick, GA: Brunswick Golden Isles', 0.6029411764705882),
#  ('Savannah, GA: Savannah/Hilton Head International', 0.6019332161687171),
#  ('Sandpoint, AK: Sand Point', 0.6015037593984962),
#  ('La Crosse, WI: La Crosse Municipal', 0.600547195622435),
#  ('Bristol/Johnson City/Kingsport, TN: Tri-Cities Regional TN/VA',
#   0.6001440922190202),
#  ('Atlanta, GA: Dekalb Peachtree', 0.6),
#  ('Chandler, AZ: Chandler Municipal', 0.6),
#  ('Elko, NV: Elko Regional', 0.6),
#  ('Ogdensburg, NY: Ogdensburg International', 0.6),
#  ('Wolf Point, MT: L. M. Clayton', 0.6),
#  ('Newport, OR: Newport Municipal', 0.6),
#  ('Cape Lisburne, AK: Cape Lisburne LRRS', 0.5980392156862745),
#  ('Trenton, NJ: Trenton Mercer', 0.5975254730713246),
#  ('Escanaba, MI: Delta County', 0.5956521739130435),
#  ('Eagle, AK: Eagle Airport', 0.5952380952380952),
#  ('Dothan, AL: Dothan Regional', 0.5952380952380952),
#  ('Riverton/Lander, WY: Riverton Regional', 0.5952380952380952),
#  ('Hagerstown, MD: Hagerstown Regional-Richard A. Henson Field',
#   0.5952380952380952),
#  ('Mountain Village, AK: Mountain Village Airport', 0.5942028985507246),
#  ('Kiana, AK: Bob Baker Memorial', 0.5939849624060151),
#  ('East Hampton, NY: East Hampton Airport', 0.5933734939759037),
#  ('Camp Springs, MD: Joint Base Andrews', 0.5927536231884057),
#  ('Goodnews Bay, AK: Goodnews', 0.5923423423423423),
#  ('Pocatello, ID: Pocatello Regional', 0.5922190201729106),
#  ('Aberdeen, SD: Aberdeen Regional', 0.5909090909090909),
#  ('Watertown, SD: Watertown Regional', 0.5901639344262295),
#  ('Pasco/Kennewick/Richland, WA: Tri Cities', 0.5893011216566005),
#  ('Kake, AK: Kake Seaplane Base', 0.5882352941176471),
#  ('Ruby, AK: Ruby Airport', 0.5880149812734082),
#  ('Pellston, MI: Pellston Regional Airport of Emmet County',
#   0.5873983739837398),
#  ('Hot Springs, AR: Memorial Field', 0.5853658536585366),
#  ('Mission/McAllen/Edinburg, TX: McAllen Miller International',
#   0.5835777126099707),
#  ('Columbus, OH: Rickenbacker International', 0.5832888414308596),
#  ('Cape Romanzof, AK: Cape Romanzof LRRS', 0.5821917808219178),
#  ('Tin City, AK: Tin City LRRS', 0.5819672131147541),
#  ('Liberal, KS: Liberal Mid-America Regional', 0.5813953488372093),
#  ('Wichita, KS: McConnell AFB', 0.5813953488372093),
#  ('Huntsville, AL: Huntsville International-Carl T Jones Field',
#   0.5813015753938484),
#  ('Pensacola, FL: Pensacola Gulf Coast Regional', 0.5804501175680215),
#  ('Hooper Bay, AK: Hooper Bay Airport', 0.5803814713896458),
#  ('Durango, CO: Durango La Plata County', 0.579295154185022),
#  ('Newport News/Williamsburg, VA: Newport News/Williamsburg International',
#   0.5782778864970646),
#  ('Jackson/Vicksburg, MS: Jackson Medgar Wiley Evers International',
#   0.5780386740331491),
#  ('Charlottesville, VA: Charlottesville Albemarle', 0.5764966740576497),
#  ('Kaltag, AK: Kaltag Airport', 0.575920245398773),
#  ('Ithaca/Cortland, NY: Ithaca Tompkins Regional', 0.5752032520325203),
#  ('Long Beach, CA: Long Beach Airport', 0.5748818611414032),
#  ('Chattanooga, TN: Lovell Field', 0.5744288872512896),
#  ('West Palm Beach/Palm Beach, FL: Palm Beach International',
#   0.5743899805657525),
#  ('Akron, OH: Akron-Canton Regional', 0.5742927429274293),
#  ('Marble Canyon, AZ: Marble Canyon Airport', 0.5714285714285714),
#  ('Williamsport, PA: Williamsport Regional', 0.5714285714285714),
#  ('Norfolk, VA: Norfolk International', 0.5713634706525702),
#  ('Wrangell, AK: Wrangell Airport', 0.5701754385964912),
#  ('Rock Springs, WY: Rock Springs Sweetwater County', 0.5696969696969697),
#  ('Klamath Falls, OR: Klamath Falls Airport', 0.5675675675675675),
#  ('Flint, MI: Bishop International', 0.5674379232505643),
#  ('Dodge City, KS: Dodge City Regional', 0.5673076923076923),
#  ('Shungnak, AK: Shungnak Airport', 0.5672645739910314),
#  ('Napakiak, AK: Napakiak Airport', 0.5654952076677316),
#  ('Syracuse, NY: Syracuse Hancock International', 0.5650144476550345),
#  ('Shishmaref, AK: Shishmaref Airport', 0.5643564356435643),
#  ('Marion/Herrin, IL: Williamson County Regional', 0.563953488372093),
#  ('Harrisburg, PA: Harrisburg International', 0.5636405904916889),
#  ('Lake Charles, LA: Lake Charles Regional', 0.5633408071748879),
#  ('Alexandria, LA: Alexandria International', 0.5625268586162441),
#  ('North Bend/Coos Bay, OR: Southwest Oregon Regional', 0.5612244897959183),
#  ('Lazy Bay, AK: Alitak Seaplane Base', 0.5609756097560976),
#  ('North Platte, NE: North Platte Regional Airport Lee Bird Field',
#   0.5606060606060606),
#  ('Albany, NY: Albany International', 0.5605773436360986),
#  ('New Stuyahok, AK: New Stuyahok Airport', 0.560377358490566),
#  ('Monroe, LA: Monroe Regional', 0.5591939546599496),
#  ('Great Falls, MT: Great Falls International', 0.5588703261734288),
#  ('Noatak, AK: Noatak Airport', 0.5580524344569289),
#  ('Reno, NV: Reno/Tahoe International', 0.5580458322840595),
#  ('Newtok, AK: Newtok Airport', 0.5573770491803278),
#  ('Johnstown, PA: John Murtha Johnstown-Cambria County', 0.5564516129032258),
#  ('Roswell, NM: Roswell International Air Center', 0.556390977443609),
#  ('Chino, CA: Chino Airport', 0.5555555555555556),
#  ('Stevens Village, AK: Stevens Village Airport', 0.5547945205479452),
#  ('Kalamazoo, MI: Kalamazoo/Battle Creek International', 0.55420054200542),
#  ('Wilmington, OH: Wilmington Air Park', 0.5540540540540541),
#  ('Fayetteville, AR: Drake Field', 0.5538922155688623),
#  ('Appleton, WI: Outagamie County Regional', 0.5537974683544303),
#  ('Rockland, ME: Knox County Regional', 0.55),
#  ('Wilmington, DE: New Castle', 0.5492424242424242),
#  ('Manley Hot Springs, AK: Manley Hot Springs Airport', 0.5490196078431373),
#  ('Arcata/Eureka, CA: Arcata', 0.5482456140350878),
#  ('Saginaw/Bay City/Midland, MI: MBS International', 0.5477855477855478),
#  ('Venetie, AK: Venetie Airport', 0.5476190476190477),
#  ('Springfield, MO: Springfield-Branson National', 0.5470552519732848),
#  ('Beverly, MA: Beverly Municipal', 0.5454545454545454),
#  ('Bloomington/Normal, IL: Central Illinois Regional', 0.5453053184504267),
#  ('Grand Junction, CO: Grand Junction Regional', 0.5432030820033021),
#  ('Denton, TX: Denton Municipal', 0.5428571428571428),
#  ('Chalkyitsik, AK: Chalkyitsik Airport', 0.5426356589147286),
#  ('Jacksonville, FL: Jacksonville International', 0.5414381245773536),
#  ('Rocky Mount, NC: Rocky Mount-Wilson Regional', 0.5405405405405406),
#  ('Kahului, HI: Kahului Airport', 0.5401563610518835),
#  ('Buffalo, NY: Buffalo Niagara International', 0.5400200458190149),
#  ('Idaho Falls, ID: Idaho Falls Regional', 0.5396341463414634),
#  ('Concord, NH: Concord Municipal', 0.5392156862745098),
#  ('Fort Dodge, IA: Fort Dodge Regional', 0.5392156862745098),
#  ('Yuma, AZ: Yuma MCAS/Yuma International', 0.5392156862745098),
#  ('Midland/Odessa, TX: Midland International', 0.5386740331491713),
#  ('West Point, AK: West Point Village', 0.5384615384615384),
#  ('Harrison, AR: Boone County', 0.5384615384615384),
#  ('Roanoke, VA: Roanoke Regional/Woodrum Field', 0.537891617273497),
#  ('Del Rio, TX: Del Rio International', 0.5377551020408163),
#  ('Alakanuk, AK: Alakanuk Airport', 0.5377358490566038),
#  ('Twin Falls, ID: Joslin Field - Magic Valley Regional', 0.5369369369369369),
#  ('Houston, TX: William P Hobby', 0.5367464048672567),
#  ('Fresno, CA: Fresno Yosemite International', 0.5354984894259819),
#  ('Holy Cross, AK: Holy Cross Airport', 0.5348837209302325),
#  ('Montgomery, AL: Montgomery Regional', 0.5338345864661654),
#  ('Hancock/Houghton, MI: Houghton County Memorial', 0.5337837837837838),
#  ('Latrobe, PA: Arnold Palmer Regional', 0.5336322869955157),
#  ('Gainesville, FL: Gainesville Regional', 0.5331550802139038),
#  ('Ashland, WV: Tri-State/Milton J. Ferguson Field', 0.5318602261048304),
#  ('Mosinee, WI: Central Wisconsin', 0.5318396226415094),
#  ('Wilmington, NC: Wilmington International', 0.5305755395683454),
#  ('Helena, MT: Helena Regional', 0.5304878048780488),
#  ('Arctic Village, AK: Arctic Village Airport', 0.5297029702970297),
#  ('Asheville, NC: Asheville Regional', 0.5295717199184229),
#  ('Alamosa, CO: San Luis Valley Regional/Bergman Field', 0.5294117647058824),
#  ('Point Hope, AK: Point Hope Airport', 0.5289855072463768),
#  ('Fayetteville, AR: Northwest Arkansas Regional', 0.5287009063444109),
#  ('Valparaiso, FL: Northwest Florida Regional', 0.5281090289608177),
#  ('Sidney, MT: Sidney/Richland Municipal', 0.5263157894736842),
#  ('Kwethluk, AK: Kwethluk Airport', 0.5254424778761062),
#  ('Togiak, AK: Togiak Airport', 0.5246305418719212),
#  ('Kobuk, AK: Kobuk Airport', 0.5245535714285714),
#  ('Hays, KS: Hays Regional', 0.524390243902439),
#  ('Amarillo, TX: Rick Husband Amarillo International', 0.5231347106026977),
#  ('Lubbock, TX: Lubbock Preston Smith International', 0.5228219525448289),
#  ('Russian Mission, AK: Russian Mission Airport', 0.5213793103448275),
#  ('Joplin, MO: Joplin Regional', 0.5203252032520326),
#  ('Myrtle Beach, SC: Myrtle Beach International', 0.5200997195387971),
#  ('Mobile, AL: Mobile Downtown', 0.5183673469387755),
#  ('Green Bay, WI: Austin Straubel International', 0.5182795698924731),
#  ('Coldfoot, AK: Coldfoot Airport', 0.5163934426229508),
#  ('Harlingen/San Benito, TX: Valley International', 0.5161166538756715),
#  ('Kwigillingok, AK: Kwigillingok Airport', 0.515695067264574),
#  ('South Bend, IN: South Bend Airport', 0.5155718537414966),
#  ('Augusta, GA: Augusta Regional at Bush Field', 0.5153908464965573),
#  ('Morgantown, WV: Morgantown Municipal-Walter L. Bill Hart Field',
#   0.5151515151515151),
#  ('Columbus, MS: Golden Triangle Regional', 0.5137221269296741),
#  ('Duluth, MN: Duluth International', 0.5129770992366413),
#  ('Lafayette, LA: Lafayette Regional', 0.5126918536009445),
#  ('Palmer, AK: Palmer Municipal', 0.5112781954887218),
#  ('Jackson, MS: Hawkins Field', 0.5112781954887218),
#  ('Peoria, IL: General Downing - Peoria International', 0.5097524381095274),
#  ('Hyannis, MA: Barnstable Municipal-Boardman/Polando Field',
#   0.5094339622641509),
#  ('Terre Haute, IN: Terre Haute International-Hulman Field',
#   0.5074349442379182),
#  ('Tyonek, AK: Tyonek Airport', 0.5068493150684932),
#  ('Santa Fe, NM: Santa Fe Municipal', 0.5065645514223195),
#  ('New Bern/Morehead/Beaufort, NC: Coastal Carolina Regional',
#   0.5060240963855421),
#  ('San Diego, CA: San Diego International', 0.5054739652870494),
#  ('Lewiston, ID: Lewiston Nez Perce County', 0.5048143053645117),
#  ('Texarkana, AR: Texarkana Regional-Webb Field', 0.5042372881355932),
#  ('Tallahassee, FL: Tallahassee Regional', 0.5034740092640247),
#  ('Little Rock, AR: Bill and Hillary Clinton Nat Adams Field',
#   0.5026338514680484),
#  ('Dayton, OH: James M Cox/Dayton International', 0.5017475066064274),
#  ('Sparrevohn, AK: Sparrevohn LRRS', 0.5),
#  ('Hamilton, NY: Hamilton Municipal', 0.5),
#  ('Lake Havasu City, AZ: Lake Havasu City Airport', 0.5),
#  ('St. Cloud, MN: St. Cloud Regional', 0.5),
#  ('Yakima, WA: Yakima Air Terminal/McAllister Field', 0.5),
#  ('Findlay, OH: Findlay Airport', 0.5),
#  ('Lawrenceville, GA: Gwinnett County - Briscoe Field', 0.5),
#  ('Petersburg, AK: Petersburg James A Johnson', 0.5),
#  ('Plymouth, MA: Plymouth Municipal', 0.5),
#  ('Lawrence, MA: Lawrence Municipal', 0.5),
#  ('Broomfield, CO: Rocky Mountain Metropolitan', 0.5),
#  ('Oxford, MS: University-Oxford', 0.5),
#  ('Presque Isle/Houlton, ME: Northern Maine Regional at Presque Isle', 0.5),
#  ('Elizabethtown, KY: Addington Field', 0.5),
#  ('Mobile, AL: Mobile Regional', 0.4991755976916735),
#  ('Greensboro/High Point, NC: Piedmont Triad International',
#   0.49855761733977855),
#  ('Bowling Green, KY: Bowling Green-Warren County Regional',
#   0.49744463373083475),
#  ('Minot, ND: Minot International', 0.4967490247074122),
#  ('Prescott, AZ: Ernest A. Love Field', 0.4956140350877193),
#  ('Kearney, NE: Kearney Regional', 0.4941860465116279),
#  ('Santa Barbara, CA: Santa Barbara Municipal', 0.4940445365095805),
#  ('Honolulu, HI: Honolulu International', 0.49279981114258736),
#  ('Albuquerque, NM: Albuquerque International Sunport', 0.49121454993834773),
#  ('Hughes, AK: Hughes Airport', 0.49107142857142855),
#  ('Charleston, SC: Charleston AFB/International', 0.49019774974428915),
#  ('Scammon Bay, AK: Scammon Bay Airport', 0.49003067484662577),
#  ('Sioux City, IA: Sioux Gateway/Col. Bud Day Field', 0.49),
#  ('Pittsburgh, PA: Pittsburgh International', 0.48933339150161415),
#  ('Jamestown, NY: Chautauqua County/Jamestown', 0.4880952380952381),
#  ('Redding, CA: Redding Municipal', 0.4876237623762376),
#  ('Bangor, ME: Bangor International', 0.48710558252427183),
#  ('Tampa, FL: Tampa International', 0.48389968838106545),
#  ('St. Michael, AK: St. Michael Airport', 0.48282967032967034),
#  ('Coffman Cove, AK: Coffman Cove Seaplane Base', 0.4823529411764706),
#  ('El Paso, TX: Biggs AAF', 0.4818181818181818),
#  ('Birmingham, AL: Birmingham-Shuttlesworth International',
#   0.48178084870608173),
#  ('Greer, SC: Greenville-Spartanburg International', 0.4808299330202479),
#  ('Bozeman, MT: Bozeman Yellowstone International', 0.4808066083576288),
#  ('Anaktuvuk Pass, AK: Anaktuvuk Pass Airport', 0.4807692307692308),
#  ('Beaumont/Port Arthur, TX: Jack Brooks Regional', 0.4798387096774194),
#  ('Medford, OR: Rogue Valley International - Medford', 0.4788819875776398),
#  ('Flagstaff, AZ: Flagstaff Pulliam', 0.47844827586206895),
#  ('Tanana, AK: Ralph M Calhoun Memorial', 0.4777227722772277),
#  ('New Orleans, LA: Louis Armstrong New Orleans International',
#   0.4767431713063967),
#  ('Santa Ana, CA: John Wayne Airport-Orange County', 0.47655794991263833),
#  ('Lewisburg, WV: Greenbrier Valley', 0.47619047619047616),
#  ('Akhiok, AK: Akhiok Airport', 0.47540983606557374),
#  ('Fort Collins/Loveland, CO: Fort Collins-Loveland Municipal',
#   0.4752941176470588),
#  ('Chevak, AK: Chevak Airport', 0.47520661157024796),
#  ('Provo, UT: Provo Municipal', 0.47418244406196214),
#  ('Columbus, OH: Port Columbus International', 0.47386768196202533),
#  ('Tulsa, OK: Tulsa International', 0.4725578857098308),
#  ('Worcester, MA: Worcester Regional', 0.4722222222222222),
#  ('Moab, UT: Canyonlands Field', 0.47115384615384615),
#  ('Atlantic City, NJ: Atlantic City International', 0.47106401384083046),
#  ('East Farmingdale, NY: Republic', 0.47063142437591776),
#  ('Manhattan/Ft. Riley, KS: Manhattan Regional', 0.4697125256673511),
#  ('Staunton, VA: Shenandoah Valley Regional', 0.4695121951219512),
#  ('Boise, ID: Boise Air Terminal', 0.4682698064258631),
#  ('Modesto, CA: Modesto City-County-Harry Sham Field', 0.46710526315789475),
#  ('Port Hueneme, CA: Point Mugu NAS', 0.4666666666666667),
#  ('Wichita Falls, TX: Sheppard AFB/Wichita Falls Municipal',
#   0.46647230320699706),
#  ('Cedar Rapids/Iowa City, IA: The Eastern Iowa', 0.4662944300694539),
#  ('Platinum, AK: Platinum Airport', 0.46629213483146065),
#  ('Casper, WY: Casper/Natrona County International', 0.46594827586206894),
#  ('San Angelo, TX: San Angelo Regional/Mathis Field', 0.464735516372796),
#  ('Kokomo/Logansport/Peru, IN: Kokomo Municipal', 0.4642857142857143),
#  ('Cincinnati, OH: Cincinnati Municipal Lunken Field', 0.46405228758169936),
#  ('Bismarck/Mandan, ND: Bismarck Municipal', 0.462890625),
#  ('Rapid City, SD: Rapid City Regional', 0.46287593984962405),
#  ('Columbia, SC: Columbia Metropolitan', 0.46198401642349146),
#  ('Knoxville, TN: McGhee Tyson', 0.46185019564002233),
#  ('Plattsburgh, NY: Plattsburgh International', 0.46174863387978143),
#  ('Denver, CO: Centennial', 0.46153846153846156),
#  ('Bridgeport, CT: Igor I Sikorsky Memorial', 0.46153846153846156),
#  ('New York, NY: LaGuardia', 0.46095695482034865),
#  ('Parkersburg, WV: Mid-Ohio Valley Regional', 0.46),
#  ('Springfield, IL: Abraham Lincoln Capital', 0.4598290598290598),
#  ('Cincinnati, OH: Cincinnati/Northern Kentucky International',
#   0.45951455570797134),
#  ('Rockford, IL: Chicago/Rockford International', 0.4585480093676815),
#  ('Abilene, TX: Abilene Regional', 0.45796713794421096),
#  ('Bedford, MA: Laurence G Hanscom Field', 0.45711060948081267),
#  ('Oklahoma City, OK: Will Rogers World', 0.4565829563290555),
#  ('Raleigh/Durham, NC: Raleigh-Durham International', 0.45463869463869466),
#  ('Brownsville, TX: Brownsville South Padre Island International',
#   0.4541577825159915),
#  ('Clarksburg/Fairmont, WV: North Central West Virginia', 0.4538860103626943),
#  ('Nashville, TN: Nashville International', 0.4538222068488412),
#  ('Toksook, AK: Toksook Bay', 0.45222929936305734),
#  ('Ontario, CA: Ontario International', 0.45138173302107726),
#  ('Omaha, NE: Eppley Airfield', 0.4513277062411435),
#  ('Chicago, IL: Chicago Midway International', 0.45103486051879965),
#  ('Grand Rapids, MI: Gerald R. Ford International', 0.45032277213029603),
#  ('Corpus Christi, TX: Corpus Christi International', 0.45003162555344717),
#  ('Greenville, MS: Greenville Mid Delta', 0.45),
#  ('Westfield, MA: Westfield Barnes Regional', 0.45),
#  ('Salem, OR: McNary Field', 0.45),
#  ('Williston, ND: Sloulin Field International', 0.449874686716792),
#  ('Fort Wayne, IN: Fort Wayne International', 0.4495165138766796),
#  ('Richmond, VA: Richmond International', 0.4490966600546829),
#  ('Spokane, WA: Spokane International', 0.4478187288454306),
#  ('Corvallis, OR: Corvallis Municipal', 0.4473684210526316),
#  ('Chicago, IL: Du Page County', 0.4470198675496689),
#  ('Des Moines, IA: Des Moines International', 0.4469721660908676),
#  ('Brainerd, MN: Brainerd Lakes Regional', 0.44696969696969696),
#  ('San Antonio, TX: San Antonio International', 0.44626038781163435),
#  ('Sioux Falls, SD: Joe Foss Field', 0.4450731707317073),
#  ('Tucson, AZ: Tucson International', 0.44502374561222385),
#  ('Madison, WI: Dane County Regional-Truax Field', 0.4444780243502288),
#  ('Hickory, NC: Hickory Regional', 0.4444444444444444),
#  ('Cabarrus, NC: Concord Regional', 0.4440268183665177),
#  ('Tuscaloosa, AL: Tuscaloosa Regional', 0.4438976377952756),
#  ('Lawton/Fort Sill, OK: Lawton-Fort Sill Regional', 0.4434782608695652),
#  ('Cordova, AK: Merle K Mudhole Smith', 0.44329896907216493),
#  ('Eugene, OR: Mahlon Sweet Field', 0.442889454339836),
#  ('Eureka, CA: Murray Field', 0.4423076923076923),
#  ('Colorado Springs, CO: City of Colorado Springs Municipal',
#   0.44158927449200475),
#  ('Grand Canyon, AZ: Grand Canyon National Park', 0.43859649122807015),
#  ('Moline, IL: Quad City International', 0.4377462568951931),
#  ('Lincoln, NE: Lincoln Airport', 0.4372793598493763),
#  ('Cold Bay, AK: Cold Bay Airport', 0.437137330754352),
#  ('Wichita, KS: Wichita Mid-Continent', 0.43625159371015726),
#  ('Moses Lake, WA: Grant County International', 0.43333333333333335),
#  ('Lansing, MI: Capital Region International', 0.43322000971345315),
#  ('San Jose, CA: Norman Y. Mineta San Jose International',
#   0.43164047073690864),
#  ('DuBois, PA: DuBois Regional', 0.43137254901960786),
#  ('Barrow, AK: Wiley Post/Will Rogers Memorial', 0.43103448275862066),
#  ('Eek, AK: Eek Airport', 0.4307511737089202),
#  ('Salina, KS: Salina Regional', 0.43028322440087147),
#  ('Santa Maria, CA: Santa Maria Public/Capt. G. Allan Hancock Field',
#   0.42806603773584906),
#  ('Thorne Bay, AK: Thorne Bay Seaplane Base', 0.42786069651741293),
#  ('Columbus, GA: Columbus Airport', 0.4273371732388126),
#  ('Sacramento, CA: Sacramento International', 0.4268837803320562),
#  ('Gulfport/Biloxi, MS: Gulfport-Biloxi International', 0.42572209211553474),
#  ('Anniston, AL: Anniston Regional', 0.4255952380952381),
#  ('Dover, DE: Dover AFB', 0.42452830188679247),
#  ('College Station/Bryan, TX: Easterwood Field', 0.42442188381274676),
#  ('Cape Newenham, AK: Cape Newenham LRRS', 0.4230769230769231),
#  ('Farmington, NM: Four Corners Regional', 0.4222222222222222),
#  ('St. Louis, MO: Lambert-St. Louis International', 0.4212327558832869),
#  ('Lewiston/Auburn, ME: Auburn Lewiston Municipal', 0.42105263157894735),
#  ('Kalskag, AK: Kalskag Airport', 0.42033898305084744),
#  ('Portsmouth, NH: Portsmouth International at Pease', 0.42003853564547206),
#  ('Seattle, WA: Boeing Field/King County International', 0.41972205795387346),
#  ('Fort Smith, AR: Fort Smith Regional', 0.41875),
#  ('Unalaska, AK: Unalaska Airport', 0.4173151750972763),
#  ('Grand Island, NE: Central Nebraska Regional', 0.4144981412639405),
#  ('Craig, AK: Craig Seaplane Base', 0.4144144144144144),
#  ('Fort Lauderdale, FL: Fort Lauderdale-Hollywood International',
#   0.41304917787183043),
#  ('Minneapolis/St. Paul, MN: St. Paul Downtown Holman Field',
#   0.4117647058823529),
#  ('Tyler, TX: Tyler Pounds Regional', 0.4111519607843137),
#  ('Sitka, AK: Sitka Rocky Gutierrez', 0.40977443609022557),
#  ('Killeen, TX: Robert Gray AAF', 0.40843465045592703),
#  ('Orlando, FL: Orlando International', 0.4076935279187817),
#  ('Milwaukee, WI: General Mitchell International', 0.40717785035629456),
#  ('Baton Rouge, LA: Baton Rouge Metropolitan/Ryan Field', 0.4070918887432649),
#  ('Deadhorse, AK: Deadhorse Airport', 0.40702479338842973),
#  ('Austin, TX: Austin - Bergstrom International', 0.40686255995769915),
#  ('Kansas City, MO: Kansas City International', 0.40684053301111),
#  ('Waco, TX: Waco Regional', 0.4066025908900961),
#  ('Billings, MT: Billings Logan International', 0.4063295743906875),
#  ('Gaylord, MI: Gaylord Regional', 0.40625),
#  ('Indianapolis, IN: Indianapolis International', 0.4055156393495759),
#  ('Gary, IN: Gary/Chicago International', 0.4046153846153846),
#  ('Washington, DC: Ronald Reagan Washington National', 0.4036867114533836),
#  ('Cleveland, OH: Cleveland-Hopkins International', 0.4034977952568228),
#  ('Olympia, WA: Olympia Regional', 0.4),
#  ('New York, NY: John F. Kennedy International', 0.39911709364596903),
#  ('Utopia, AK: Indian Mountain LRRS', 0.39705882352941174),
#  ('Tupelo, MS: Tupelo Regional', 0.3948339483394834),
#  ('Lexington, KY: Blue Grass', 0.3937004986799648),
#  ('Pueblo, CO: Pueblo Memorial', 0.39288522012578614),
#  ('Galena, AK: Edward G. Pitka Sr.', 0.3906480117820324),
#  ('Pierre, SD: Pierre Regional', 0.38963963963963966),
#  ('Nogales, AZ: Nogales International', 0.38922155688622756),
#  ('Jonesboro, AR: Jonesboro Municipal', 0.3888888888888889),
#  ('Boston, MA: Logan International', 0.38778658820996736),
#  ('Oakland, CA: Metropolitan Oakland International', 0.3871617144895775),
#  ('Cedar City, UT: Cedar City Regional', 0.38650306748466257),
#  ('Hoonah, AK: Hoonah Airport', 0.38650306748466257),
#  ('Belmar/Farmingdale, NJ: Monmouth Executive', 0.38461538461538464),
#  ('Grand Forks, ND: Grand Forks International', 0.3839920948616601),
#  ('Philadelphia, PA: Philadelphia International', 0.3827438243094252),
#  ('Westhampton, NY: Francis S. Gabreski', 0.38235294117647056),
#  ('Florence, SC: Florence Regional', 0.38235294117647056),
#  ('St. Petersburg, FL: St. Petersburg-Clearwater International',
#   0.3810054088450525),
#  ('Dallas, TX: Dallas Love Field', 0.3809858472276076),
#  ('Portland, OR: Portland International', 0.38092997508995297),
#  ('Baltimore, MD: Baltimore/Washington International Thurgood Marshall',
#   0.38034530386740334),
#  ('Toledo, OH: Toledo Express', 0.37952146375791695),
#  ('Lakeland, FL: Lakeland Linder Regional', 0.37755102040816324),
#  ('Everett, WA: Snohomish County', 0.3763440860215054),
#  ('Waterloo, IA: Waterloo Regional', 0.37479806138933763),
#  ('Hattiesburg/Laurel, MS: Hattiesburg-Laurel Regional', 0.37475728155339805),
#  ('Chicopee Falls, MA: Westover ARB Metropolitan', 0.37438423645320196),
#  ('El Paso, TX: El Paso International', 0.3741499033574343),
#  ('Shreveport, LA: Shreveport Regional', 0.3735440931780366),
#  ('Charlotte, NC: Charlotte Douglas International', 0.3706708860759494),
#  ('Niagara Falls, NY: Niagara Falls International', 0.3695652173913043),
#  ('Pontiac, MI: Oakland County International', 0.368230111427831),
#  ('Las Vegas, NV: North Las Vegas', 0.36585365853658536),
#  ('Bettles, AK: Bettles Airport', 0.3653100775193798),
#  ('Mason City, IA: Mason City Municipal', 0.36363636363636365),
#  ("St. Mary's, AK: St. Mary's Airport", 0.3633241758241758),
#  ('Cheyenne, WY: Cheyenne Regional/Jerry Olson Field', 0.3630926954293037),
#  ('Thief River Falls, MN: Thief River Falls Regional', 0.35784313725490197),
#  ('Phoenix, AZ: Phoenix Sky Harbor International', 0.35773406766325727),
#  ('Fort Yukon, AK: Fort Yukon Airport', 0.35714285714285715),
#  ('Detroit, MI: Coleman A. Young Municipal', 0.35714285714285715),
#  ('Smyrna, TN: Smyrna Airport', 0.35493955814922884),
#  ('Newark, NJ: Newark Liberty International', 0.3542668825161887),
#  ('Ogden, UT: Ogden-Hinckley', 0.3537234042553192),
#  ('Jackson, TN: McKellar-Sipes Regional', 0.35294117647058826),
#  ('Kenai, AK: Kenai Municipal', 0.3524590163934426),
#  ('San Francisco, CA: San Francisco International', 0.3511502285347335),
#  ('Iliamna, AK: Iliamna Airport', 0.35047169811320755),
#  ('Fairbanks, AK: Ladd AAF', 0.3490990990990991),
#  ('Valdosta, GA: Valdosta Regional', 0.34615384615384615),
#  ('Louisville, KY: Louisville International-Standiford Field',
#   0.3441218265498738),
#  ('Miami, FL: Miami International', 0.34398214840550234),
#  ('Van Nuys, CA: Van Nuys Airport', 0.3438003220611916),
#  ('Fargo, ND: Hector International', 0.34345945945945944),
#  ('Miami, FL: Opa-locka Executive', 0.33967391304347827),
#  ('Pendleton, OR: Eastern Oregon Regional at Pendleton', 0.33653846153846156),
#  ('Dallas, TX: Addison', 0.3364695340501792),
#  ('Salt Lake City, UT: Salt Lake City International', 0.33606844186290635),
#  ('Youngstown/Warren, OH: Youngstown-Warren Regional', 0.33483348334833485),
#  ('Talladega, AL: Talladega Municipal', 0.3333333333333333),
#  ('Olive Branch, MS: Olive Branch Airport', 0.3333333333333333),
#  ('Orlando, FL: Kissimmee Gateway', 0.3333333333333333),
#  ('Port Alexander, AK: Port Alexander Airport', 0.3333333333333333),
#  ('Belfast, ME: Belfast Municipal', 0.3333333333333333),
#  ('Mattoon/Charleston, IL: Coles County Memorial', 0.3333333333333333),
#  ('McGrath, AK: McGrath Airport', 0.33224346076458755),
#  ('Seattle, WA: Seattle/Tacoma International', 0.33046826526515566),
#  ('Dillingham, AK: Dillingham Airport', 0.3281544256120527),
#  ('Washington, DC: Washington Dulles International', 0.3277365341474132),
#  ('Unalakleet, AK: Unalakleet Airport', 0.32211538461538464),
#  ('Riverside, CA: March ARB', 0.3202247191011236),
#  ('Bradford, PA: Bradford Regional', 0.3173913043478261),
#  ('Gaithersburg, MD: Montgomery County Airpark', 0.3157894736842105),
#  ('Memphis, TN: Memphis International', 0.31334898390738686),
#  ('Detroit, MI: Detroit Metro Wayne County', 0.3132383926555798),
#  ('Houston, TX: George Bush Intercontinental/Houston', 0.3053587751371115),
#  ('Las Vegas, NV: McCarran International', 0.3007018061497608),
#  ('Victorville, CA: Southern California Logistics', 0.3),
#  ('Troutdale, OR: Portland Troutdale', 0.3),
#  ('Punta Gorda, FL: Punta Gorda Airport', 0.29931972789115646),
#  ('Page, AZ: Page Municipal', 0.29646017699115046),
#  ('Watertown, NY: Watertown International', 0.29069767441860467),
#  ('Scottsbluff, NE: Western Neb. Regional/William B. Heilig Field',
#   0.2886690647482014),
#  ('King Salmon, AK: King Salmon Airport', 0.28668261562998404),
#  ('Dallas/Fort Worth, TX: Dallas/Fort Worth International',
#   0.2834487815532466),
#  ('Aniak, AK: Aniak Airport', 0.28265376641326884),
#  ('Kotzebue, AK: Ralph Wien Memorial', 0.2747228381374723),
#  ('Los Angeles, CA: Los Angeles International', 0.2738882840633113),
#  ('Laredo, TX: Laredo International', 0.2722393980050166),
#  ('Homer, AK: Homer Airport', 0.2671232876712329),
#  ('Ketchikan, AK: Ketchikan International', 0.26068965517241377),
#  ("Chicago, IL: Chicago O'Hare International", 0.2590840220385675),
#  ('Sanford, FL: Orlando Sanford International', 0.25695719215801455),
#  ('Tok, AK: Tok Junction', 0.25),
#  ('Tacoma, WA: McChord Field', 0.25),
#  ('New London/Groton, CT: Groton-New London', 0.25),
#  ('Anchorage, AK: Elmendorf AFB', 0.24528301886792453),
#  ('Waterbury, CT: Waterbury Oxford', 0.24390243902439024),
#  ('Las Vegas, NV: Nellis AFB', 0.24285714285714285),
#  ('Nome, AK: Nome Airport', 0.24274661508704062),
#  ('Atlanta, GA: Hartsfield-Jackson Atlanta International', 0.2405890430418107),
#  ('Juneau, AK: Juneau International', 0.23952434881087203),
#  ('Bullhead City, AZ: Laughlin/Bullhead International', 0.23921106953941426),
#  ('Anchorage, AK: Merrill Field', 0.2364341085271318),
#  ('White Plains, NY: Westchester County', 0.22855003523608175),
#  ("Martha's Vineyard, MA: Martha's Vineyard Airport", 0.22592067988668554),
#  ('Minneapolis, MN: Minneapolis-St Paul International', 0.22334913998025185),
#  ('Philadelphia, PA: Northeast Philadelphia', 0.21951219512195122),
#  ('Denver, CO: Denver International', 0.2099596061600606),
#  ('Teterboro, NJ: Teterboro Airport', 0.1995339970345266),
#  ('Detroit, MI: Willow Run', 0.1889215051775148),
#  ('Burbank, CA: Bob Hope', 0.1875337905130467),
#  ('Bethel, AK: Bethel Airport', 0.18617643237625048),
#  ('Wendover, UT: Wendover Airport', 0.1809221516872703),
#  ('Hopkinsville, KY: Campbell AAF', 0.16666666666666666),
#  ('Mountain View, CA: Moffett Federal Airfield', 0.16666666666666666),
#  ('Newport News/Hampton, VA: Langley AFB', 0.16666666666666666),
#  ('Knob Noster, MO: Whiteman AFB', 0.16666666666666666),
#  ('Kodiak, AK: Kodiak Airport', 0.15524402907580478),
#  ('Nantucket, MA: Nantucket Memorial', 0.1544943820224719),
#  ('Fort Lauderdale, FL: Fort Lauderdale Executive', 0.14285714285714285),
#  ('Fairbanks, AK: Fairbanks International', 0.10840758510395247),
#  ('Anchorage, AK: Ted Stevens Anchorage International', 0.10642477467067252),
#  ('Fairfield, CA: Travis AFB', 0.1),
#  ('Hamilton, OH: Butler County Regional Hogan Field', 0.1),
#  ('Dallas/Fort Worth, TX: Fort Worth Meacham International',
#   0.07692307692307693),
#  ('New Iberia, LA: Acadiana Regional', 0.07692307692307693),
#  ('Pogo Mines, AK: Pogo Mines Airport', 0),
#  ('Rampart, AK: Hunter Creek', 0),
#  ('Cordova, AK: Cordova Municipal', 0),
#  ('Kizhuyak, AK: Kizhuyak Bay', 0),
#  ('Ninilchik, AK: Ninilchik Airport', 0),
#  ('Whitebear, AK: Whitebear Airport', 0),
#  ('Cape Simpson, AK: Cape Simpson Airport', 0),
#  ('Carbondale, IL: Southern Illinois', 0),
#  ("Coeur d'Alene, ID: Coeur d'Alene - Pappy Boyington Field", 0),
#  ('Davis/Woodland/Winters, CA: Yolo County', 0),
#  ('Fort Worth, TX: Fort Worth Spinks', 0),
#  ('Indianapolis, IN: Indianapolis Executive', 0),
#  ('Mesquite, TX: Mesquite Metro', 0),
#  ('Ely, NV: Ely Airport/Yelland Field', 0),
#  ('Ironwood, MI: Gogebic-Iron County', 0),
#  ('Mount Pleasant, MI: Mount Pleasant Municipal', 0),
#  ('Kulik Lake, AK: Kulik Lake Airport', 0),
#  ('Funter Bay Alaska, AK: Funter Bay', 0),
#  ('Gulkana, AK: Gulkana Airport', 0),
#  ('May Creek, AK: May Creek Airport', 0),
#  ('Oxnard/Ventura, CA: Oxnard', 0),
#  ('Whidbey Island, WA: Whidbey Island NAS', 0),
#  ('Kamuela, HI: Waimea-Kohala', 0),
#  ('Shemya, AK: Eareckson AS', 0),
#  ('Boundary, AK: Boundary Airport', 0),
#  ('Talkeetna, AK: Talkeetna Airport', 0),
#  ('Skwentna, AK: Skwentna Airport', 0),
#  ('Kayenta, AZ: Kayenta Airport', 0),
#  ('Bryce Canyon, UT: Bryce Canyon Airport', 0),
#  ('Blairstown, NJ: Blairstown Airport', 0),
#  ('Clemson, SC: Oconee County Regional', 0),
#  ('Clarksville, TN: Outlaw Field', 0),
#  ('Carlsbad, NM: Cavern City Air Terminal', 0),
#  ('Los Alamos, NM: Los Alamos Airport', 0),
#  ('Natchez, MS: Hardy-Anders Field Natchez-Adams County', 0),
#  ('Waukegan, IL: Waukegan Regional', 0),
#  ('Block Island, RI: Block Island State', 0),
#  ('Cherry Point, NC: Cherry Point MCAS', 0),
#  ('Edenton, NC: Northeastern Regional', 0),
#  ('Sugar Land, TX: Sugar Land Regional', 0),
#  ('Rogers, AR: Rogers Municipal Carter Field', 0),
#  ('Kirksville, MO: Kirksville Regional', 0),
#  ('Fort Leonard Wood, MO: Waynesville-St. Robert Regional Forney Field', 0),
#  ('Quincy, IL: Quincy Regional-Baldwin Field', 0),
#  ('Massena, NY: Massena International-Richards Field', 0),
#  ('Marshfield, WI: Marshfield Municipal', 0),
#  ('Nashua, NH: Boire Field', 0),
#  ('Selinsgrove, PA: Penn Valley', 0),
#  ('Columbus, NE: Columbus Municipal', 0),
#  ('Naples, FL: Naples Municipal', 0),
#  ('Edwards, CA: Edwards AFB', 0),
#  ('Glens Falls, NY: Floyd Bennett Memorial', 0),
#  ('Pine Bluff, AR: Grider Field', 0),
#  ('Hartford, CT: Hartford Brainard', 0),
#  ('Poughkeepsie, NY: Dutchess County', 0),
#  ('Westerly, RI: Westerly State', 0),
#  ('Toms River, NJ: Ocean County', 0),
#  ('Tucson, AZ: Davis Monthan AFB', 0),
#  ('Annapolis, MD: Lee', 0),
#  ('Jacksonville, IL: Jacksonville Municipal', 0),
#  ('Concord, CA: Buchanan Field', 0),
#  ('Miami, FL: Kendall-Tamiami Executive', 0)]

# %%
data
# Out:
#       ORIGIN DEST     PAYLOAD  DISTANCE    SEATS  PASSENGERS  \
# 0        ANC  OME  33729908.0     539.0  31762.0     20623.0
# 1        ATK  OME      4500.0     463.0     19.0         0.0
# 2        AUK  OME     39300.0     129.0     26.0         7.0
# 3        BET  OME     84200.0     283.0    346.0       260.0
# 4        BRW  OME     59180.0     520.0    253.0       132.0
# ...      ...  ...         ...       ...      ...         ...
# 19004    MTM  KPB      1850.0     116.0      6.0         0.0
# 19005    LGD  HES      6900.0      71.0      0.0         0.0
# 19006    OXR  CCR      2000.0     306.0      8.0         3.0
# 19007    HAO  UOX      2000.0     442.0      8.0         2.0
# 19008    IJX  MFI      2000.0     336.0      8.0         2.0
#
#        DEPARTURES_PERFORMED  \
# 0                    1133.0
# 1                       1.0
# 2                       9.0
# 3                      18.0
# 4                      13.0
# ...                     ...
# 19004                   1.0
# 19005                   2.0
# 19006                   1.0
# 19007                   1.0
# 19008                   1.0
#
#                                             CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0      ['Era Aviation' 'Alaska Airlines Inc.'\n 'Tato...            10299.0
# 1                          ['Hageland Aviation Service']            10396.0
# 2      ['Arctic Transportation' 'Bering Air Inc.' 'Ha...            10416.0
# 3      ['Hageland Aviation Service' 'Bering Air Inc.'...            10551.0
# 4      ['Bering Air Inc.' 'Era Aviation' 'Hageland Av...            10754.0
# ...                                                  ...                ...
# 19004    ['Venture Travel LLC d/b/a Taquan Air Service']            13504.0
# 19005  ['Empire Airlines Inc.' 'Federal Express Corpo...            12956.0
# 19006                              ['Avjet Corporation']            13988.0
# 19007                              ['Avjet Corporation']            12068.0
# 19008                              ['Avjet Corporation']            12310.0
#
#        DEST_AIRPORT_ID                                        ORIGIN_NAME  \
# 0              13873.0  Anchorage, AK: Ted Stevens Anchorage Internati...
# 1              13873.0   Atqasuk, AK: Atqasuk Edward Burnell Sr. Memorial
# 2              13873.0                     Alakanuk, AK: Alakanuk Airport
# 3              13873.0                         Bethel, AK: Bethel Airport
# 4              13873.0        Barrow, AK: Wiley Post/Will Rogers Memorial
# ...                ...                                                ...
# 19004          12773.0                        Metlakatla, AK: Metlakatala
# 19005          12103.0              La Grande, OR: La Grande/Union County
# 19006          10910.0                         Oxnard/Ventura, CA: Oxnard
# 19007          15481.0   Hamilton, OH: Butler County Regional Hogan Field
# 19008          13260.0           Jacksonville, IL: Jacksonville Municipal
#
#                                   DEST_NAME          ORIGIN_LAT  \
# 0                    Nome, AK: Nome Airport             61.1744
# 1                    Nome, AK: Nome Airport            70.46704
# 2                    Nome, AK: Nome Airport  62.680042266799994
# 3                    Nome, AK: Nome Airport         60.77980042
# 4                    Nome, AK: Nome Airport           71.285402
# ...                                     ...                 ...
# 19004  Point Baker, AK: Point Baker Airport           55.131001
# 19005    Hermiston, OR: Hermiston Municipal       45.2901992798
# 19006           Concord, CA: Buchanan Field     34.200801849365
# 19007         Oxford, MS: University-Oxford  39.363800048799995
# 19008  Marshfield, WI: Marshfield Municipal  39.774600982666016
#
#               ORIGIN_LONG           DEST_LAT            DEST_LONG
# 0             -149.996002  64.51219940185547  -165.44500732421875
# 1             -157.436013  64.51219940185547  -165.44500732421875
# 2          -164.659927368  64.51219940185547  -165.44500732421875
# 3            -161.8379974  64.51219940185547  -165.44500732421875
# 4             -156.766008  64.51219940185547  -165.44500732421875
# ...                   ...                ...                  ...
# 19004         -131.578003      56.3518981934       -133.623001099
# 19005      -118.007003784      38.6534996033       -122.899002075
# 19006    -119.20700073242      37.9897003174       -122.056999207
# 19007      -84.5220031738    34.384300231934     -89.536796569824
# 19008  -90.23829650878906      44.6369018555   -90.18930053710001
#
# [19009 rows x 16 columns]

# %%
li = []
coef = []
for elm in clustering_sorted:
    if elm[1] in [1,0]:
        li.append(elm[0])
        coef.append(elm[1])

# %%
d = {"ORIGIN_NAME": li, "COEFFICIENT": coef}
df_coef = pd.DataFrame(data=d)

# %%
mask = data["ORIGIN_NAME"].isin(li)

# %%
to_florian_dataframe = data[mask][["ORIGIN_NAME","ORIGIN_LAT","ORIGIN_LONG"]].drop_duplicates('ORIGIN_NAME', keep='last')

# %%
to_florian_dataframe = pd.merge(to_florian_dataframe, df_coef, on = ["ORIGIN_NAME"])

# %%
to_florian_dataframe.to_csv('../../Data/to_florian_clustering_coefficient.csv', index=False)

# %%
#Clustering coefficient plottet

# %%
t = [x[1] for x in clustering_sorted]
plt.hist(t, bins = 50);

# %%
#Degree distribution

# %%
def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees, bins = 30)
    plt.show()

plot_degree_dist(G)

# %%
#Degree distribution
def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.loglog(degrees)
    plt.show()

plot_degree_dist(G)

# %%
#Degree distribution
#It does not follow the power law
def plot_degree_dist(G):
    degrees = [n[1] for n in G.degree]
    plt.loglog(degrees)
    plt.gca().invert_yaxis()
    plt.show()

plot_degree_dist(G)
